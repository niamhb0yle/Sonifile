# %%
# Test pop up, self reflection is the best!!

# %%
# %load_ext autoreload
# %autoreload 2
# %run sonifile_prototype.py
# %reload_ext sonifile_prototype
# %select_from_dummy_folder
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Directory: .ipynb_checkpoints
#   File: prototypeNotebook-checkpoint.ipynb
#   File: test4.txt
#   File: Untitled-checkpoint.ipynb
#   File: Untitled1-checkpoint.ipynb
#   File: Untitled2-checkpoint.ipynb
#   File: Untitled3-checkpoint.ipynb
#   File: Untitled4-checkpoint.ipynb
# File: jupyter_extension.py
# File: prototypeNotebook.ipynb
# File: sonifile_prototype.py
# File: test3.txt
# Directory: TestProject
#   Directory: Docs
#     File: bigDoc.docx
#     File: bigDoc.txt
#     File: smallDoc.docx
#     File: smallDoc2.txt
#     File: test2.txt
#     File: test5.txt
#     File: usefulDocument.docx
#     File: usefulDocument.txt
#   Directory: python
#     File: .gitignore
#     File: gilded_rose.py
#     File: test_gilded_rose.py
#     File: texttest_fixture.py
#   File: test6.txt
# File: Untitled.ipynb
# File: untitled.txt
# File: Untitled1.ipynb
# File: Untitled2.ipynb
# File: Untitled3.ipynb
# File: Untitled4.ipynb
# Directory: __pycache__
#   File: jupyter_extension.cpython-38.pyc
#   File: sonifile_prototype.cpython-38.pyc
#   File: test1.txt
# prototypeNotebook-checkpoint.ipynb
# test4.txt
# Untitled-checkpoint.ipynb
# Untitled1-checkpoint.ipynb
# Untitled2-checkpoint.ipynb
# Untitled3-checkpoint.ipynb
# Untitled4-checkpoint.ipynb
# jupyter_extension.py
# prototypeNotebook.ipynb
# sonifile_prototype.py
# test3.txt
# bigDoc.docx
# bigDoc.txt
# smallDoc.docx
# smallDoc2.txt
# test2.txt
# test5.txt
# usefulDocument.docx
# usefulDocument.txt
# .gitignore
# gilded_rose.py
# test_gilded_rose.py
# texttest_fixture.py
# test6.txt
# Untitled.ipynb
# untitled.txt
# Untitled1.ipynb
# Untitled2.ipynb
# Untitled3.ipynb
# Untitled4.ipynb
# jupyter_extension.cpython-38.pyc
# sonifile_prototype.cpython-38.pyc
# test1.txt
# Select a filetest1.txt
#
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\__pycache__\test1.txt
# __pycache__
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\__pycache__\test1.txt
# test1.txt
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\__pycache__\test1.txt
# Select a filetest1.txt
#
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\__pycache__\test1.txt
# __pycache__
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\__pycache__\test1.txt
# test1.txt
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\__pycache__\test1.txt
# Select a filetest3.txt
# Select a filetest4.txt
#
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\.ipynb_checkpoints\test4.txt
# .ipynb_checkpoints
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\.ipynb_checkpoints\test4.txt
# test4.txt
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\.ipynb_checkpoints\test4.txt
# Select a filetest1.txt
#
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\__pycache__\test1.txt
# __pycache__
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\__pycache__\test1.txt
# test1.txt
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\__pycache__\test1.txt
# Select a filetest2.txt
#
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\TestProject\Docs\test2.txt
# TestProject
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\TestProject\Docs\test2.txt
# Docs
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\TestProject\Docs\test2.txt
# test2.txt
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\TestProject\Docs\test2.txt
# Select a filetest3.txt
# Select a filetest4.txt
#
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\.ipynb_checkpoints\test4.txt
# .ipynb_checkpoints
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\.ipynb_checkpoints\test4.txt
# test4.txt
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\.ipynb_checkpoints\test4.txt
# Select a filetest5.txt
#
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\TestProject\Docs\test5.txt
# TestProject
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\TestProject\Docs\test5.txt
# Docs
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\TestProject\Docs\test5.txt
# test5.txt
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\TestProject\Docs\test5.txt
# Select a filetest6.txt
#
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\TestProject\test6.txt
# TestProject
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\TestProject\test6.txt
# test6.txt
# C:\Users\orrja\uni\Level4\HCI\Sonifile\Sonifile\PrototypeJupterNotebook\TestProject\test6.txt

# %%
# %select_from_dummy_folder
