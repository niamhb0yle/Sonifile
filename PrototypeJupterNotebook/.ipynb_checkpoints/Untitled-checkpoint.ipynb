# %%
import sounddevice as sd
import numpy as np
import time
 
def play_file_size(file_size_mbytes):
    sd.play(file_size_mbytes * np.sin(0.1*np.arange(176400/3)), 44100)
    
    
    
def main():
    for i in range(10):
        play_file_size(1)
        time.sleep(0.1)
        play_file_size(3)
main()

# %%
import os

def list_files_in_current_directory():
    current_directory = os.getcwd()
    files = [f for f in os.listdir(current_directory) if os.path.isfile(os.path.join(current_directory, f))]
 
    return files

files_in_current_directory = list_files_in_current_directory()


file_size_dict = {}
print("Files in the current directory:")
for file in files_in_current_directory:
    f = open(file, "r")
    f.readline()
    counter = 0
    while f.readline() != "":
        counter = counter +1
    print(file, counter)
    file_size_dict[file] = counter
    f.close()
    
    
def input_file():
    user_input = input("select a file")
    if user_input in file_size_dict:
        size = file_size_dict[user_input] / 100
        play_file_size(size)
    else:
        print("file not found")
        
input_file()
# Out:
# Files in the current directory:
# prototypeNotebook.ipynb 224
# Untitled.ipynb 177
# untitled.txt 30
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-f0272512fcef> in <module>
#      31         print("file not found")
#      32
# ---> 33 input_file()
#
# <ipython-input-20-f0272512fcef> in input_file()
#      24
#      25 def input_file():
# ---> 26     user_input = input("select a file")
#      27     if user_input in file_size_dict:
#      28         size = file_size_dict[user_input] / 100
#
# ~\anaconda3333\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3333\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import os

def list_directory_tree_with_indentation(directory, indent=0):
    for item in os.listdir(directory):
        item_path = os.path.join(directory, item)
        if os.path.isfile(item_path):
            print(f"{'  ' * indent}File: {item}")
        elif os.path.isdir(item_path):
            print(f"{'  ' * indent}Directory: {item}")
            list_directory_tree_with_indentation(item_path, indent+1)
        print(item_path)
        try:
            f = open(item_path, "r")
            print(f.readline())
        except:
            print("file wont open")
            
list_directory_tree_with_indentation("C:")
# Out:
# Directory: .ipynb_checkpoints
#   File: Untitled-checkpoint.ipynb
# C:.ipynb_checkpoints\Untitled-checkpoint.ipynb
# {
#
# C:.ipynb_checkpoints
# file wont open
# File: prototypeNotebook.ipynb
# C:prototypeNotebook.ipynb
# {
#
# Directory: TestProject
#   Directory: Docs
#     File: bigDoc.docx
# C:TestProject\Docs\bigDoc.docx
# file wont open
#     File: smallDoc.docx
# C:TestProject\Docs\smallDoc.docx
# file wont open
#     File: usefulDocument.docx
# C:TestProject\Docs\usefulDocument.docx
# file wont open
# C:TestProject\Docs
# file wont open
#   Directory: python
#     File: .gitignore
# C:TestProject\python\.gitignore
# *.pyc
#
#     Directory: .idea
#       File: .gitignore
# C:TestProject\python\.idea\.gitignore
# # Default ignored files
#
#       File: misc.xml
# C:TestProject\python\.idea\misc.xml
# <?xml version="1.0" encoding="UTF-8"?>
#
#       File: modules.xml
# C:TestProject\python\.idea\modules.xml
# <?xml version="1.0" encoding="UTF-8"?>
#
#       File: python.iml
# C:TestProject\python\.idea\python.iml
# <?xml version="1.0" encoding="UTF-8"?>
#
#       File: vcs.xml
# C:TestProject\python\.idea\vcs.xml
# <?xml version="1.0" encoding="UTF-8"?>
#
#       File: workspace.xml
# C:TestProject\python\.idea\workspace.xml
# <?xml version="1.0" encoding="UTF-8"?>
#
# C:TestProject\python\.idea
# file wont open
#     File: gilded_rose.py
# C:TestProject\python\gilded_rose.py
# # -*- coding: utf-8 -*-
#
#     File: test_gilded_rose.py
# C:TestProject\python\test_gilded_rose.py
# # -*- coding: utf-8 -*-
#
#     File: texttest_fixture.py
# C:TestProject\python\texttest_fixture.py
# # -*- coding: utf-8 -*-
#
# C:TestProject\python
# file wont open
#   Directory: Src
#     Directory: Main
# C:TestProject\Src\Main
# file wont open
# C:TestProject\Src
# file wont open
#   Directory: Test
# C:TestProject\Test
# file wont open
# C:TestProject
# file wont open
# File: Untitled.ipynb
# C:Untitled.ipynb
# {
#
# File: untitled.txt
# C:untitled.txt
# test file
